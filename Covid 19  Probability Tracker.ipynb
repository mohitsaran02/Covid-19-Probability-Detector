# %%
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv(r'F:\Programming\Python\Project\Covid 19 Solution\data.csv')

# %%
df.head()
# Out:
#         fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 0   98.610963         0   54          1           0              1
# 1  101.211489         1   49          0           0              1
# 2   99.808486         0   52          1          -1              0
# 3   98.870883         1   15          1           1              0
# 4  101.963638         0   71          1           1              1

# %%
df.tail()
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 1995   98.210756         0   70          0          -1              1
# 1996  101.649188         1   41          0           1              1
# 1997  101.541826         1   54          0           0              1
# 1998  100.771969         0   58          1           1              1
# 1999  101.184913         1   39          1          -1              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
# fever            2000 non-null float64
# bodyPain         2000 non-null int64
# age              2000 non-null int64
# runnyNose        2000 non-null int64
# diffBreath       2000 non-null int64
# infectionProb    2000 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 93.8 KB

# %%
df['diffBreath'].value_counts()
# Out:
#  1    702
# -1    655
#  0    643
# Name: diffBreath, dtype: int64

# %%
df.describe()
# Out:
#              fever     bodyPain          age    runnyNose   diffBreath  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     99.965701     0.497000    50.648000     0.503500     0.023500
# std       1.177356     0.500116    28.245849     0.500113     0.823582
# min      98.000145     0.000000     1.000000     0.000000    -1.000000
# 25%      98.906384     0.000000    27.000000     0.000000    -1.000000
# 50%      99.991551     0.000000    51.000000     1.000000     0.000000
# 75%     100.975710     1.000000    75.000000     1.000000     1.000000
# max     101.999606     1.000000   100.000000     1.000000     1.000000
#
#        infectionProb
# count    2000.000000
# mean        0.505500
# std         0.500095
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # Train Test Splitting

# %%
import numpy as np

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data)*ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = data_split(df, 0.2)

# %%
train
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 968    98.003345         1   22          0           0              0
# 240   101.468463         0   76          0           1              0
# 819    98.244355         0   47          1           0              1
# 692    99.411353         1   56          1           1              1
# 420   101.783319         1    6          0           1              0
# 1085  101.824581         1   73          0           0              0
# 1998  100.771969         0   58          1           1              1
# 365    98.244421         1   56          1           1              0
# 1022  101.618934         1   79          1           0              0
# 1240  100.398494         1   17          1           1              1
# 588   100.373550         1   58          1           0              1
# 584   100.370912         0   34          0          -1              0
# 374   101.937650         1   47          1          -1              0
# 275   100.516607         1   45          1           0              1
# 746    98.476115         1   59          0           0              0
# 128   101.542392         0   52          1           0              0
# 1646   99.703043         1   94          0           0              1
# 1852  101.419831         0   59          0           0              1
# 674    99.140429         0   47          0           1              1
# 1664   99.911180         1   76          1          -1              1
# 1981   99.829535         0   12          1           1              1
# 1083  101.204633         0   29          0          -1              1
# 1922   99.318859         0   76          0          -1              1
# 99    101.981063         0   49          1          -1              1
# 1179  101.095940         1   34          1          -1              1
# 964   100.827751         1   56          0           0              1
# 792    98.691773         0   34          0          -1              1
# 29     99.959033         1   54          0           1              1
# ...          ...       ...  ...        ...         ...            ...
# 1543   98.891666         1    1          1           0              1
# 1803  101.300677         0    9          1           0              0
# 67    101.797897         0   85          0          -1              0
# 1737  101.074720         1   85          1          -1              1
# 1592  100.244305         0   23          1           1              1
# 1563  101.330852         1   87          0          -1              0
# 480    99.067359         0   46          1           1              1
# 1756   99.145244         1   36          1          -1              0
# 1912   99.427923         0   37          1           1              1
# 1440  100.727295         0   30          0          -1              1
# 1460  100.388293         1   51          1          -1              0
# 887    98.151567         0    2          1           1              0
# 422    99.494358         0    8          0           0              0
# 1674  100.976561         1   91          0           1              1
# 1449   98.102554         1   41          1           1              0
# 764   100.190759         1   83          0          -1              0
# 519   101.490375         1   76          1           0              1
# 1431   99.638509         1   24          1           1              1
# 613   100.709812         1   50          0           1              1
# 1530   99.700839         0    7          0          -1              0
# 1782  100.461831         1   56          1           1              1
# 1658   98.131104         0   20          0           0              1
# 453    99.790682         1   12          0           1              0
# 730    98.329731         0   28          1           0              1
# 534   100.755721         1    8          1          -1              1
# 965    98.400262         1   81          1           1              0
# 1284   99.436198         1   34          0           0              0
# 1739  101.866479         1   18          0           0              1
# 261   101.623971         0   12          0           1              0
# 535   101.751154         1   17          0           1              0
#
# [400 rows x 6 columns]

# %%
X_train = train[['fever','bodyPain', 'age', 'runnyNose', 'diffBreath']].to_numpy()
X_test = test[['fever','bodyPain', 'age', 'runnyNose', 'diffBreath']].to_numpy()

# %%
Y_train = train[['infectionProb']].to_numpy().reshape(1600 ,)
Y_test = test[['infectionProb']].to_numpy().reshape(400 ,)

# %%
Y_train
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
inputFeatures = [100, 1, 22, -1, 1]
infProb = clf.predict_proba([inputFeatures])[0][1]

# %%
infProb
# Out:
# 0.4858152440270045

# %%
pwd
# Out:
# 'C:\\Users\\ASUS'
